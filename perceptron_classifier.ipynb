# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from Perceptron import Perceptron

# %%
X = np.random.randn(500,2)
y = np.ones(500) 

y[:250] *= -1
X[:250] += 4

df = pd.DataFrame(X, columns=['x1', 'x2'])
df['y'] = y

df.head()
# Out:
#          x1        x2    y
# 0  3.174569  4.118350 -1.0
# 1  5.541167  5.116760 -1.0
# 2  3.780874  2.162326 -1.0
# 3  4.090923  3.997821 -1.0
# 4  3.843898  1.996615 -1.0

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
perceptron = Perceptron()
w,b,iter = perceptron.fit(X, y)

plt.scatter(X[:,0], X[:,1], c=y)
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                     np.arange(y_min, y_max, 0.01))
Z = perceptron.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3)
plt.show()
print('Perceptron weights:', w)
print('Perceptron bias:', b)
print('Perceptron converged in {} iterations'.format(iter))
# Out:
# Perceptron weights: [-1.92506369 -0.8034496 ]
# Perceptron bias: 5.0
# Perceptron converged in 3 iterations

# %%
X_test = np.array([
    [1,1],
    [6,3],
    [2,5],
    [4,1],
    [-2,2]
])

preds = perceptron.predict(X_test)

print(preds)
# Out:
# [ 1. -1. -1. -1.  1.]
